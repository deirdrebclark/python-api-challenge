# %% [markdown]
# ## Observable trends based on the data:
#
# 1.  The lower the city is from the equator, the higher the maximum temperature.
#
# 2.  The latitude did not matter as much as to how cloudy or windy a city would be.
#
# 3.  A city's huidity was not dependent on the city's latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = '../output_data/cities.csv'

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code #city.country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
city_count = len(cities)

print(f'City count:  {city_count}')
# Out:
# City count:  606

# %%
#Retrieve the latitude and longitude from citipy

#Set up variables
city_name = ''
i = 0
print_count = 0
record_count = 0
set_count = 1

Country = []
Lat = []
Lng = []
Date = []
Max_Temp = []
Humidity = []
Cloudiness = []
Wind_Speed = []

#Begin retrieval
pprint(f'Beginning Data Retrieval')
pprint(f'-----------------------------')

if record_count < city_count: 
         
    for city in cities:

        city_name = city
        record_count += 1

        if print_count < 100:

            print_count += 1
            
            w_response = requests.get('https://api.openweathermap.org/data/2.5/weather?q=' + city_name 
                                      + '&units=imperial' + '&APPID=' + weather_api_key).json()
            try:

                pprint(f'Processing Record {print_count} in Set {set_count} | {city}')
                
                Country.append(w_response['sys']['country'])
                Lat.append(w_response['coord']['lat'])
                Lng.append(w_response['coord']['lon'])
                Date.append(w_response['dt'])
                Cloudiness.append(w_response['clouds']['all'])
                Max_Temp.append(w_response['main']['temp_max'])
                Humidity.append(w_response['main']['humidity'])
                Wind_Speed.append(w_response['wind']['speed'])

            except (KeyError, IndexError):
                pprint(f'Missing information for {city_name}. Skipping...')
           

        else:

            set_count += 1
            print_count = 0

pprint(f'-----------------------------')
pprint(f'Data Retrieval Complete')
pprint(f'-----------------------------')
# Out:
# 'Beginning Data Retrieval'
# '-----------------------------'
# 'Processing Record 1 in Set 1 | rikitea'
# 'Processing Record 2 in Set 1 | albany'
# 'Processing Record 3 in Set 1 | port elizabeth'
# 'Processing Record 4 in Set 1 | faanui'
# 'Processing Record 5 in Set 1 | barrow'
# 'Processing Record 6 in Set 1 | ayr'
# 'Processing Record 7 in Set 1 | champerico'
# 'Processing Record 8 in Set 1 | pevek'
# 'Processing Record 9 in Set 1 | dawei'
# 'Processing Record 10 in Set 1 | tumannyy'
# 'Missing information for tumannyy. Skipping...'
# 'Processing Record 11 in Set 1 | vaitupu'
# 'Missing information for vaitupu. Skipping...'
# 'Processing Record 12 in Set 1 | punta arenas'
# 'Processing Record 13 in Set 1 | carnarvon'
# 'Processing Record 14 in Set 1 | puerto ayora'
# 'Processing Record 15 in Set 1 | hobart'
# 'Processing Record 16 in Set 1 | biak'
# 'Processing Record 17 in Set 1 | port hedland'
# 'Processing Record 18 in Set 1 | provideniya'
# 'Processing Record 19 in Set 1 | ciudad bolivar'
# 'Processing Record 20 in Set 1 | bethel'
# 'Processing Record 21 in Set 1 | mataura'
# 'Processing Record 22 in Set 1 | fort nelson'
# 'Processing Record 23 in Set 1 | ushuaia'
# 'Processing Record 24 in Set 1 | saint-philippe'
# 'Processing Record 25 in Set 1 | grand river south east'
# 'Missing information for grand river south east. Skipping...'
# 'Processing Record 26 in Set 1 | puerto baquerizo moreno'
# 'Processing Record 27 in Set 1 | kapaa'
# 'Processing Record 28 in Set 1 | hervey bay'
# 'Processing Record 29 in Set 1 | garowe'
# 'Processing Record 30 in Set 1 | barentsburg'
# 'Missing information for barentsburg. Skipping...'
# 'Processing Record 31 in Set 1 | thompson'
# 'Processing Record 32 in Set 1 | mys shmidta'
# 'Missing information for mys shmidta. Skipping...'
# 'Processing Record 33 in Set 1 | rorvik'
# 'Processing Record 34 in Set 1 | hermanus'
# 'Processing Record 35 in Set 1 | petropavlovsk-kamchatskiy'
# 'Processing Record 36 in Set 1 | celano'
# 'Processing Record 37 in Set 1 | taolanaro'
# 'Missing information for taolanaro. Skipping...'
# 'Processing Record 38 in Set 1 | naryan-mar'
# 'Processing Record 39 in Set 1 | maningrida'
# 'Processing Record 40 in Set 1 | port alfred'
# 'Processing Record 41 in Set 1 | jian'
# 'Processing Record 42 in Set 1 | collie'
# 'Processing Record 43 in Set 1 | mae hong son'
# 'Processing Record 44 in Set 1 | victoria'
# 'Processing Record 45 in Set 1 | jiddah'
# 'Missing information for jiddah. Skipping...'
# 'Processing Record 46 in Set 1 | saldanha'
# 'Processing Record 47 in Set 1 | bluff'
# 'Processing Record 48 in Set 1 | portland'
# 'Processing Record 49 in Set 1 | broken hill'
# 'Processing Record 50 in Set 1 | ouadda'
# 'Processing Record 51 in Set 1 | baker city'
# 'Processing Record 52 in Set 1 | tasiilaq'
# 'Processing Record 53 in Set 1 | kahului'
# 'Processing Record 54 in Set 1 | kavieng'
# 'Processing Record 55 in Set 1 | tiksi'
# 'Processing Record 56 in Set 1 | busselton'
# 'Processing Record 57 in Set 1 | maniitsoq'
# 'Processing Record 58 in Set 1 | illoqqortoormiut'
# 'Missing information for illoqqortoormiut. Skipping...'
# 'Processing Record 59 in Set 1 | new norfolk'
# 'Processing Record 60 in Set 1 | saint-leu'
# 'Processing Record 61 in Set 1 | ribeira grande'
# 'Processing Record 62 in Set 1 | chuy'
# 'Processing Record 63 in Set 1 | kaitangata'
# 'Processing Record 64 in Set 1 | fredericksburg'
# 'Processing Record 65 in Set 1 | arraial do cabo'
# 'Processing Record 66 in Set 1 | cayenne'
# 'Processing Record 67 in Set 1 | vaini'
# 'Processing Record 68 in Set 1 | clyde river'
# 'Processing Record 69 in Set 1 | hilo'
# 'Processing Record 70 in Set 1 | chekhov'
# 'Processing Record 71 in Set 1 | praia'
# 'Processing Record 72 in Set 1 | bull savanna'
# 'Processing Record 73 in Set 1 | muzhi'
# 'Processing Record 74 in Set 1 | almaznyy'
# 'Processing Record 75 in Set 1 | byron bay'
# 'Processing Record 76 in Set 1 | georgetown'
# 'Processing Record 77 in Set 1 | geraldton'
# 'Processing Record 78 in Set 1 | lukoyanov'
# 'Processing Record 79 in Set 1 | malanje'
# 'Processing Record 80 in Set 1 | qaanaaq'
# 'Processing Record 81 in Set 1 | nanortalik'
# 'Processing Record 82 in Set 1 | port blair'
# 'Processing Record 83 in Set 1 | jamestown'
# 'Processing Record 84 in Set 1 | lebu'
# 'Processing Record 85 in Set 1 | butaritari'
# 'Processing Record 86 in Set 1 | iqaluit'
# 'Processing Record 87 in Set 1 | gorlitz'
# 'Processing Record 88 in Set 1 | bredasdorp'
# 'Processing Record 89 in Set 1 | xirokambion'
# 'Missing information for xirokambion. Skipping...'
# 'Processing Record 90 in Set 1 | lugovoy'
# 'Processing Record 91 in Set 1 | ilulissat'
# 'Processing Record 92 in Set 1 | castro'
# 'Processing Record 93 in Set 1 | amahai'
# 'Processing Record 94 in Set 1 | moussoro'
# 'Processing Record 95 in Set 1 | mayumba'
# 'Processing Record 96 in Set 1 | airai'
# 'Processing Record 97 in Set 1 | kimbe'
# 'Processing Record 98 in Set 1 | nigran'
# 'Processing Record 99 in Set 1 | atuona'
# 'Processing Record 100 in Set 1 | clarence town'
# 'Processing Record 1 in Set 2 | viedma'
# 'Processing Record 2 in Set 2 | seymchan'
# 'Processing Record 3 in Set 2 | ukiah'
# 'Processing Record 4 in Set 2 | lewisporte'
# 'Processing Record 5 in Set 2 | aquidauana'
# 'Processing Record 6 in Set 2 | goderich'
# 'Processing Record 7 in Set 2 | toliary'
# 'Missing information for toliary. Skipping...'
# 'Processing Record 8 in Set 2 | karamea'
# 'Missing information for karamea. Skipping...'
# 'Processing Record 9 in Set 2 | ginir'
# 'Processing Record 10 in Set 2 | cape town'
# 'Processing Record 11 in Set 2 | touros'
# 'Processing Record 12 in Set 2 | jutai'
# 'Processing Record 13 in Set 2 | sokode'
# 'Processing Record 14 in Set 2 | tsihombe'
# 'Missing information for tsihombe. Skipping...'
# 'Processing Record 15 in Set 2 | amderma'
# 'Missing information for amderma. Skipping...'
# 'Processing Record 16 in Set 2 | aripuana'
# 'Processing Record 17 in Set 2 | norman wells'
# 'Processing Record 18 in Set 2 | mayskiy'
# 'Processing Record 19 in Set 2 | salalah'
# 'Processing Record 20 in Set 2 | tacuarembo'
# 'Processing Record 21 in Set 2 | naftah'
# 'Missing information for naftah. Skipping...'
# 'Processing Record 22 in Set 2 | severo-kurilsk'
# 'Processing Record 23 in Set 2 | coquimbo'
# 'Processing Record 24 in Set 2 | vaasa'
# 'Processing Record 25 in Set 2 | kirakira'
# 'Processing Record 26 in Set 2 | orje'
# 'Processing Record 27 in Set 2 | dikson'
# 'Processing Record 28 in Set 2 | cidreira'
# 'Processing Record 29 in Set 2 | nguiu'
# 'Missing information for nguiu. Skipping...'
# 'Processing Record 30 in Set 2 | egvekinot'
# 'Processing Record 31 in Set 2 | beringovskiy'
# 'Processing Record 32 in Set 2 | hithadhoo'
# 'Processing Record 33 in Set 2 | tucuman'
# 'Processing Record 34 in Set 2 | shirokiy'
# 'Processing Record 35 in Set 2 | asyut'
# 'Processing Record 36 in Set 2 | safi'
# 'Processing Record 37 in Set 2 | cherskiy'
# 'Processing Record 38 in Set 2 | correntina'
# 'Processing Record 39 in Set 2 | moyale'
# 'Processing Record 40 in Set 2 | necochea'
# 'Processing Record 41 in Set 2 | hambantota'
# 'Processing Record 42 in Set 2 | osinovo'
# 'Processing Record 43 in Set 2 | caravelas'
# 'Processing Record 44 in Set 2 | paamiut'
# 'Processing Record 45 in Set 2 | timon'
# 'Processing Record 46 in Set 2 | wampusirpi'
# 'Missing information for wampusirpi. Skipping...'
# 'Processing Record 47 in Set 2 | korhogo'
# 'Processing Record 48 in Set 2 | lazaro cardenas'
# 'Processing Record 49 in Set 2 | luderitz'
# 'Processing Record 50 in Set 2 | deputatskiy'
# 'Processing Record 51 in Set 2 | thinadhoo'
# 'Processing Record 52 in Set 2 | gamba'
# 'Processing Record 53 in Set 2 | sao filipe'
# 'Processing Record 54 in Set 2 | moryakovskiy zaton'
# 'Processing Record 55 in Set 2 | piranshahr'
# 'Processing Record 56 in Set 2 | asau'
# 'Processing Record 57 in Set 2 | lompoc'
# 'Processing Record 58 in Set 2 | antofagasta'
# 'Processing Record 59 in Set 2 | haibowan'
# 'Missing information for haibowan. Skipping...'
# 'Processing Record 60 in Set 2 | yar-sale'
# 'Processing Record 61 in Set 2 | esmeraldas'
# 'Processing Record 62 in Set 2 | puerto cabezas'
# 'Processing Record 63 in Set 2 | saint george'
# 'Processing Record 64 in Set 2 | bathsheba'
# 'Processing Record 65 in Set 2 | lindas'
# 'Processing Record 66 in Set 2 | sitka'
# 'Processing Record 67 in Set 2 | klaksvik'
# 'Processing Record 68 in Set 2 | north bend'
# 'Processing Record 69 in Set 2 | banda aceh'
# 'Processing Record 70 in Set 2 | qarqin'
# 'Processing Record 71 in Set 2 | isangel'
# 'Processing Record 72 in Set 2 | lichuan'
# 'Processing Record 73 in Set 2 | changji'
# 'Processing Record 74 in Set 2 | half moon bay'
# 'Processing Record 75 in Set 2 | karauzyak'
# 'Missing information for karauzyak. Skipping...'
# 'Processing Record 76 in Set 2 | nenjiang'
# 'Processing Record 77 in Set 2 | korla'
# 'Processing Record 78 in Set 2 | ngukurr'
# 'Missing information for ngukurr. Skipping...'
# 'Processing Record 79 in Set 2 | eureka'
# 'Processing Record 80 in Set 2 | coahuayana'
# 'Processing Record 81 in Set 2 | grindavik'
# 'Processing Record 82 in Set 2 | axim'
# 'Processing Record 83 in Set 2 | lolua'
# 'Missing information for lolua. Skipping...'
# 'Processing Record 84 in Set 2 | usinsk'
# 'Processing Record 85 in Set 2 | omsukchan'
# 'Processing Record 86 in Set 2 | prado'
# 'Processing Record 87 in Set 2 | devyatka'
# 'Missing information for devyatka. Skipping...'
# 'Processing Record 88 in Set 2 | kulachi'
# 'Processing Record 89 in Set 2 | saskylakh'
# 'Processing Record 90 in Set 2 | longyearbyen'
# 'Processing Record 91 in Set 2 | mantua'
# 'Processing Record 92 in Set 2 | lavumisa'
# 'Processing Record 93 in Set 2 | jumla'
# 'Processing Record 94 in Set 2 | balabac'
# 'Processing Record 95 in Set 2 | akyab'
# 'Processing Record 96 in Set 2 | saint-georges'
# 'Processing Record 97 in Set 2 | bambous virieux'
# 'Processing Record 98 in Set 2 | chokurdakh'
# 'Processing Record 99 in Set 2 | mahajanga'
# 'Processing Record 100 in Set 2 | panaba'
# 'Processing Record 1 in Set 3 | umzimvubu'
# 'Missing information for umzimvubu. Skipping...'
# 'Processing Record 2 in Set 3 | edd'
# 'Processing Record 3 in Set 3 | chanderi'
# 'Processing Record 4 in Set 3 | mount isa'
# 'Processing Record 5 in Set 3 | sulina'
# 'Processing Record 6 in Set 3 | nantucket'
# 'Processing Record 7 in Set 3 | san patricio'
# 'Processing Record 8 in Set 3 | tiznit'
# 'Processing Record 9 in Set 3 | matagami'
# 'Processing Record 10 in Set 3 | pemangkat'
# 'Processing Record 11 in Set 3 | walvis bay'
# 'Processing Record 12 in Set 3 | tuktoyaktuk'
# 'Processing Record 13 in Set 3 | east london'
# 'Processing Record 14 in Set 3 | upernavik'
# 'Processing Record 15 in Set 3 | mahebourg'
# 'Processing Record 16 in Set 3 | belushya guba'
# 'Missing information for belushya guba. Skipping...'
# 'Processing Record 17 in Set 3 | pacific grove'
# 'Processing Record 18 in Set 3 | henties bay'
# 'Processing Record 19 in Set 3 | petatlan'
# 'Processing Record 20 in Set 3 | yerbogachen'
# 'Processing Record 21 in Set 3 | venancio aires'
# 'Processing Record 22 in Set 3 | mount gambier'
# 'Processing Record 23 in Set 3 | sibolga'
# 'Processing Record 24 in Set 3 | msanga'
# 'Processing Record 25 in Set 3 | ebolowa'
# 'Processing Record 26 in Set 3 | shahr-e babak'
# 'Processing Record 27 in Set 3 | ituni'
# 'Missing information for ituni. Skipping...'
# 'Processing Record 28 in Set 3 | marystown'
# 'Processing Record 29 in Set 3 | srednekolymsk'
# 'Processing Record 30 in Set 3 | jacareacanga'
# 'Processing Record 31 in Set 3 | leningradskiy'
# 'Processing Record 32 in Set 3 | praia da vitoria'
# 'Processing Record 33 in Set 3 | saryshagan'
# 'Missing information for saryshagan. Skipping...'
# 'Processing Record 34 in Set 3 | ixtapa'
# 'Processing Record 35 in Set 3 | jalna'
# 'Processing Record 36 in Set 3 | lidkoping'
# 'Processing Record 37 in Set 3 | souillac'
# 'Processing Record 38 in Set 3 | vestmannaeyjar'
# 'Processing Record 39 in Set 3 | tessalit'
# 'Processing Record 40 in Set 3 | nikolskoye'
# 'Processing Record 41 in Set 3 | grande-riviere'
# 'Missing information for grande-riviere. Skipping...'
# 'Processing Record 42 in Set 3 | yarada'
# 'Processing Record 43 in Set 3 | saint-francois'
# 'Processing Record 44 in Set 3 | sao joao da barra'
# 'Processing Record 45 in Set 3 | hasaki'
# 'Processing Record 46 in Set 3 | sept-iles'
# 'Processing Record 47 in Set 3 | ithaca'
# 'Processing Record 48 in Set 3 | muisne'
# 'Processing Record 49 in Set 3 | kodiak'
# 'Processing Record 50 in Set 3 | manokwari'
# 'Processing Record 51 in Set 3 | marcona'
# 'Missing information for marcona. Skipping...'
# 'Processing Record 52 in Set 3 | talnakh'
# 'Processing Record 53 in Set 3 | aswan'
# 'Processing Record 54 in Set 3 | brody'
# 'Processing Record 55 in Set 3 | sakakah'
# 'Processing Record 56 in Set 3 | avarua'
# 'Processing Record 57 in Set 3 | jobner'
# 'Processing Record 58 in Set 3 | chitral'
# 'Processing Record 59 in Set 3 | lavrentiya'
# 'Processing Record 60 in Set 3 | ancud'
# 'Processing Record 61 in Set 3 | santa cruz'
# 'Processing Record 62 in Set 3 | nouadhibou'
# 'Processing Record 63 in Set 3 | cordoba'
# 'Processing Record 64 in Set 3 | dong xoai'
# 'Processing Record 65 in Set 3 | buala'
# 'Processing Record 66 in Set 3 | muncie'
# 'Processing Record 67 in Set 3 | phultala'
# 'Processing Record 68 in Set 3 | macas'
# 'Processing Record 69 in Set 3 | nizhneyansk'
# 'Missing information for nizhneyansk. Skipping...'
# 'Processing Record 70 in Set 3 | bodden town'
# 'Processing Record 71 in Set 3 | roberto payan'
# 'Missing information for roberto payan. Skipping...'
# 'Processing Record 72 in Set 3 | khatanga'
# 'Processing Record 73 in Set 3 | namibe'
# 'Processing Record 74 in Set 3 | cabo san lucas'
# 'Processing Record 75 in Set 3 | olafsvik'
# 'Processing Record 76 in Set 3 | waipawa'
# 'Processing Record 77 in Set 3 | aklavik'
# 'Processing Record 78 in Set 3 | torbay'
# 'Processing Record 79 in Set 3 | mandapam'
# 'Processing Record 80 in Set 3 | attawapiskat'
# 'Missing information for attawapiskat. Skipping...'
# 'Processing Record 81 in Set 3 | lencois paulista'
# 'Processing Record 82 in Set 3 | varaklani'
# 'Missing information for varaklani. Skipping...'
# 'Processing Record 83 in Set 3 | carutapera'
# 'Processing Record 84 in Set 3 | madang'
# 'Processing Record 85 in Set 3 | ponta do sol'
# 'Processing Record 86 in Set 3 | straumen'
# 'Processing Record 87 in Set 3 | sakata'
# 'Processing Record 88 in Set 3 | micomeseng'
# 'Processing Record 89 in Set 3 | sentyabrskiy'
# 'Missing information for sentyabrskiy. Skipping...'
# 'Processing Record 90 in Set 3 | fiche'
# 'Processing Record 91 in Set 3 | mar del plata'
# 'Processing Record 92 in Set 3 | wajima'
# 'Processing Record 93 in Set 3 | miles city'
# 'Processing Record 94 in Set 3 | mudgee'
# 'Processing Record 95 in Set 3 | xinqing'
# 'Processing Record 96 in Set 3 | hamilton'
# 'Processing Record 97 in Set 3 | ascension'
# 'Processing Record 98 in Set 3 | niksic'
# 'Processing Record 99 in Set 3 | letlhakane'
# 'Processing Record 100 in Set 3 | hlyboka'
# 'Processing Record 1 in Set 4 | yellowknife'
# 'Processing Record 2 in Set 4 | manado'
# 'Processing Record 3 in Set 4 | batemans bay'
# 'Processing Record 4 in Set 4 | mahon'
# 'Processing Record 5 in Set 4 | bikaner'
# 'Processing Record 6 in Set 4 | aksarka'
# 'Processing Record 7 in Set 4 | dzhebariki-khaya'
# 'Processing Record 8 in Set 4 | hof'
# 'Processing Record 9 in Set 4 | lagoa'
# 'Processing Record 10 in Set 4 | chateauroux'
# 'Processing Record 11 in Set 4 | bonavista'
# 'Processing Record 12 in Set 4 | nahrin'
# 'Processing Record 13 in Set 4 | bjornevatn'
# 'Processing Record 14 in Set 4 | vardo'
# 'Processing Record 15 in Set 4 | papasquiaro'
# 'Missing information for papasquiaro. Skipping...'
# 'Processing Record 16 in Set 4 | casian'
# 'Processing Record 17 in Set 4 | lambarene'
# 'Processing Record 18 in Set 4 | matara'
# 'Processing Record 19 in Set 4 | hirara'
# 'Processing Record 20 in Set 4 | xingyi'
# 'Processing Record 21 in Set 4 | kandalaksha'
# 'Processing Record 22 in Set 4 | dingle'
# 'Processing Record 23 in Set 4 | muros'
# 'Processing Record 24 in Set 4 | nemuro'
# 'Processing Record 25 in Set 4 | bengkulu'
# 'Processing Record 26 in Set 4 | fairbanks'
# 'Processing Record 27 in Set 4 | londoko'
# 'Processing Record 28 in Set 4 | kingman'
# 'Processing Record 29 in Set 4 | vostok'
# 'Processing Record 30 in Set 4 | inirida'
# 'Processing Record 31 in Set 4 | chapais'
# 'Processing Record 32 in Set 4 | mansa'
# 'Processing Record 33 in Set 4 | estepa'
# 'Processing Record 34 in Set 4 | kamina'
# 'Processing Record 35 in Set 4 | sola'
# 'Processing Record 36 in Set 4 | malwan'
# 'Missing information for malwan. Skipping...'
# 'Processing Record 37 in Set 4 | heiligenhafen'
# 'Processing Record 38 in Set 4 | crato'
# 'Processing Record 39 in Set 4 | umm ruwabah'
# 'Missing information for umm ruwabah. Skipping...'
# 'Processing Record 40 in Set 4 | klyuchi'
# 'Processing Record 41 in Set 4 | tromso'
# 'Processing Record 42 in Set 4 | troitsko-pechorsk'
# 'Processing Record 43 in Set 4 | rapid valley'
# 'Processing Record 44 in Set 4 | vilhena'
# 'Processing Record 45 in Set 4 | charyshskoye'
# 'Processing Record 46 in Set 4 | karaul'
# 'Missing information for karaul. Skipping...'
# 'Processing Record 47 in Set 4 | azua'
# 'Processing Record 48 in Set 4 | kedrovyy'
# 'Processing Record 49 in Set 4 | mimoso do sul'
# 'Processing Record 50 in Set 4 | jiaocheng'
# 'Processing Record 51 in Set 4 | asuncion'
# 'Processing Record 52 in Set 4 | pozo colorado'
# 'Processing Record 53 in Set 4 | khromtau'
# 'Processing Record 54 in Set 4 | samusu'
# 'Missing information for samusu. Skipping...'
# 'Processing Record 55 in Set 4 | sedelnikovo'
# 'Missing information for sedelnikovo. Skipping...'
# 'Processing Record 56 in Set 4 | karratha'
# 'Processing Record 57 in Set 4 | tome-acu'
# 'Missing information for tome-acu. Skipping...'
# 'Processing Record 58 in Set 4 | schwalmstadt'
# 'Processing Record 59 in Set 4 | ambodifototra'
# 'Missing information for ambodifototra. Skipping...'
# 'Processing Record 60 in Set 4 | vila franca do campo'
# 'Processing Record 61 in Set 4 | karasjok'
# 'Processing Record 62 in Set 4 | vila velha'
# 'Processing Record 63 in Set 4 | atasu'
# 'Processing Record 64 in Set 4 | arawa'
# 'Processing Record 65 in Set 4 | sabratah'
# 'Processing Record 66 in Set 4 | evenskjaer'
# 'Missing information for evenskjaer. Skipping...'
# 'Processing Record 67 in Set 4 | broome'
# 'Processing Record 68 in Set 4 | krasnoselkup'
# 'Processing Record 69 in Set 4 | narsaq'
# 'Processing Record 70 in Set 4 | anchorage'
# 'Processing Record 71 in Set 4 | gobabis'
# 'Processing Record 72 in Set 4 | seoul'
# 'Processing Record 73 in Set 4 | bur gabo'
# 'Missing information for bur gabo. Skipping...'
# 'Processing Record 74 in Set 4 | zhigansk'
# 'Processing Record 75 in Set 4 | tuatapere'
# 'Processing Record 76 in Set 4 | palafrugell'
# 'Processing Record 77 in Set 4 | balancan'
# 'Processing Record 78 in Set 4 | macomb'
# 'Processing Record 79 in Set 4 | mapastepec'
# 'Processing Record 80 in Set 4 | hay river'
# 'Processing Record 81 in Set 4 | basoda'
# 'Processing Record 82 in Set 4 | rocha'
# 'Processing Record 83 in Set 4 | ossora'
# 'Processing Record 84 in Set 4 | imeni zhelyabova'
# 'Processing Record 85 in Set 4 | pisco'
# 'Processing Record 86 in Set 4 | batagay-alyta'
# 'Processing Record 87 in Set 4 | ahuimanu'
# 'Processing Record 88 in Set 4 | takoradi'
# 'Processing Record 89 in Set 4 | kandi'
# 'Processing Record 90 in Set 4 | rolim de moura'
# 'Missing information for rolim de moura. Skipping...'
# 'Processing Record 91 in Set 4 | dwarka'
# 'Processing Record 92 in Set 4 | camacha'
# 'Processing Record 93 in Set 4 | fortuna'
# 'Processing Record 94 in Set 4 | wanxian'
# 'Processing Record 95 in Set 4 | trelew'
# 'Processing Record 96 in Set 4 | kununurra'
# 'Processing Record 97 in Set 4 | madera'
# 'Processing Record 98 in Set 4 | alghero'
# 'Processing Record 99 in Set 4 | huangmei'
# 'Processing Record 100 in Set 4 | camana'
# 'Processing Record 1 in Set 5 | bubaque'
# 'Processing Record 2 in Set 5 | zholymbet'
# 'Processing Record 3 in Set 5 | nelson bay'
# 'Processing Record 4 in Set 5 | tungkang'
# 'Missing information for tungkang. Skipping...'
# 'Processing Record 5 in Set 5 | maragogi'
# 'Processing Record 6 in Set 5 | olinda'
# 'Processing Record 7 in Set 5 | maceio'
# 'Processing Record 8 in Set 5 | avera'
# 'Processing Record 9 in Set 5 | salistea de sus'
# 'Processing Record 10 in Set 5 | qasigiannguit'
# 'Processing Record 11 in Set 5 | dourbali'
# 'Processing Record 12 in Set 5 | tautira'
# 'Processing Record 13 in Set 5 | plettenberg bay'
# 'Processing Record 14 in Set 5 | naze'
# 'Processing Record 15 in Set 5 | evansville'
# 'Processing Record 16 in Set 5 | komsomolskiy'
# 'Processing Record 17 in Set 5 | mongoumba'
# 'Processing Record 18 in Set 5 | port hardy'
# 'Processing Record 19 in Set 5 | lorengau'
# 'Processing Record 20 in Set 5 | wulanhaote'
# 'Missing information for wulanhaote. Skipping...'
# 'Processing Record 21 in Set 5 | cumra'
# 'Processing Record 22 in Set 5 | zhezkazgan'
# 'Processing Record 23 in Set 5 | kulu'
# 'Processing Record 24 in Set 5 | cabedelo'
# 'Processing Record 25 in Set 5 | harrison'
# 'Processing Record 26 in Set 5 | galiwinku'
# 'Missing information for galiwinku. Skipping...'
# 'Processing Record 27 in Set 5 | aleksandrovskoye'
# 'Processing Record 28 in Set 5 | sakaraha'
# 'Processing Record 29 in Set 5 | hovd'
# 'Processing Record 30 in Set 5 | ulaangom'
# 'Processing Record 31 in Set 5 | evensk'
# 'Processing Record 32 in Set 5 | katsuura'
# 'Processing Record 33 in Set 5 | ust-kuyga'
# 'Processing Record 34 in Set 5 | sarakhs'
# 'Processing Record 35 in Set 5 | tahta'
# 'Processing Record 36 in Set 5 | sault sainte marie'
# 'Processing Record 37 in Set 5 | marsh harbour'
# 'Processing Record 38 in Set 5 | sijunjung'
# 'Processing Record 39 in Set 5 | huadian'
# 'Processing Record 40 in Set 5 | gold coast'
# 'Processing Record 41 in Set 5 | guerrero negro'
# 'Processing Record 42 in Set 5 | placido de castro'
# 'Processing Record 43 in Set 5 | xiropotamos'
# 'Processing Record 44 in Set 5 | san cristobal'
# 'Processing Record 45 in Set 5 | pitkyaranta'
# 'Processing Record 46 in Set 5 | oriximina'
# 'Processing Record 47 in Set 5 | tawau'
# 'Processing Record 48 in Set 5 | mwingi'
# 'Processing Record 49 in Set 5 | marawi'
# 'Processing Record 50 in Set 5 | port lincoln'
# 'Processing Record 51 in Set 5 | ahipara'
# 'Processing Record 52 in Set 5 | zhangye'
# 'Processing Record 53 in Set 5 | hualmay'
# 'Processing Record 54 in Set 5 | flinders'
# 'Processing Record 55 in Set 5 | abbeville'
# 'Processing Record 56 in Set 5 | quatre cocos'
# 'Processing Record 57 in Set 5 | meyungs'
# 'Missing information for meyungs. Skipping...'
# 'Processing Record 58 in Set 5 | mrirt'
# 'Missing information for mrirt. Skipping...'
# 'Processing Record 59 in Set 5 | sangre grande'
# 'Processing Record 60 in Set 5 | gawan'
# 'Processing Record 61 in Set 5 | paragominas'
# 'Processing Record 62 in Set 5 | rawson'
# 'Processing Record 63 in Set 5 | guaruja'
# 'Processing Record 64 in Set 5 | benito juarez'
# 'Processing Record 65 in Set 5 | boguchany'
# 'Processing Record 66 in Set 5 | christchurch'
# 'Processing Record 67 in Set 5 | gat'
# 'Processing Record 68 in Set 5 | palabuhanratu'
# 'Missing information for palabuhanratu. Skipping...'
# 'Processing Record 69 in Set 5 | sechura'
# 'Processing Record 70 in Set 5 | bodoco'
# 'Missing information for bodoco. Skipping...'
# 'Processing Record 71 in Set 5 | vagur'
# 'Processing Record 72 in Set 5 | okhotsk'
# 'Processing Record 73 in Set 5 | alofi'
# 'Processing Record 74 in Set 5 | sabzevar'
# 'Processing Record 75 in Set 5 | westport'
# 'Processing Record 76 in Set 5 | genhe'
# 'Processing Record 77 in Set 5 | kyabe'
# 'Processing Record 78 in Set 5 | esperance'
# 'Processing Record 79 in Set 5 | kysyl-syr'
# 'Processing Record 80 in Set 5 | adana'
# 'Processing Record 81 in Set 5 | jiayuguan'
# 'Processing Record 82 in Set 5 | hammerfest'
# 'Processing Record 83 in Set 5 | palu'
# 'Processing Record 84 in Set 5 | kumano'
# 'Processing Record 85 in Set 5 | baykit'
# 'Processing Record 86 in Set 5 | sereflikochisar'
# 'Processing Record 87 in Set 5 | saa'
# 'Processing Record 88 in Set 5 | general roca'
# 'Processing Record 89 in Set 5 | lewiston'
# 'Processing Record 90 in Set 5 | grand gaube'
# 'Processing Record 91 in Set 5 | hanna'
# 'Processing Record 92 in Set 5 | loanda'
# 'Processing Record 93 in Set 5 | cururupu'
# 'Processing Record 94 in Set 5 | chirongui'
# 'Processing Record 95 in Set 5 | hofn'
# 'Processing Record 96 in Set 5 | davila'
# 'Processing Record 97 in Set 5 | bato'
# 'Processing Record 98 in Set 5 | mawlaik'
# 'Processing Record 99 in Set 5 | santander'
# 'Processing Record 100 in Set 5 | sergeyevka'
# 'Processing Record 1 in Set 6 | adamovka'
# 'Processing Record 2 in Set 6 | goedereede'
# 'Processing Record 3 in Set 6 | fukue'
# 'Processing Record 4 in Set 6 | bayan'
# 'Processing Record 5 in Set 6 | marzuq'
# 'Processing Record 6 in Set 6 | ilo'
# 'Processing Record 7 in Set 6 | port macquarie'
# 'Processing Record 8 in Set 6 | mundo nuevo'
# 'Processing Record 9 in Set 6 | nyimba'
# 'Processing Record 10 in Set 6 | dauriya'
# 'Processing Record 11 in Set 6 | alotau'
# 'Missing information for alotau. Skipping...'
# 'Processing Record 12 in Set 6 | clemson'
# 'Processing Record 13 in Set 6 | ostrovnoy'
# 'Processing Record 14 in Set 6 | papara'
# 'Processing Record 15 in Set 6 | nome'
# 'Processing Record 16 in Set 6 | los llanos de aridane'
# 'Processing Record 17 in Set 6 | launceston'
# 'Processing Record 18 in Set 6 | kruisfontein'
# 'Processing Record 19 in Set 6 | yelan-koleno'
# 'Processing Record 20 in Set 6 | labuhan'
# 'Processing Record 21 in Set 6 | calvia'
# 'Processing Record 22 in Set 6 | constitucion'
# 'Processing Record 23 in Set 6 | nizwa'
# 'Processing Record 24 in Set 6 | aguada de pasajeros'
# 'Processing Record 25 in Set 6 | ocos'
# 'Processing Record 26 in Set 6 | petrozavodsk'
# 'Processing Record 27 in Set 6 | bilibino'
# 'Processing Record 28 in Set 6 | wahran'
# 'Missing information for wahran. Skipping...'
# 'Processing Record 29 in Set 6 | jiaojiang'
# 'Processing Record 30 in Set 6 | beloha'
# 'Processing Record 31 in Set 6 | aginskoye'
# 'Processing Record 32 in Set 6 | male'
# 'Processing Record 33 in Set 6 | anadyr'
# 'Processing Record 34 in Set 6 | damietta'
# 'Processing Record 35 in Set 6 | trincomalee'
# 'Processing Record 36 in Set 6 | mentok'
# 'Missing information for mentok. Skipping...'
# 'Processing Record 37 in Set 6 | port moresby'
# 'Processing Record 38 in Set 6 | codrington'
# 'Processing Record 39 in Set 6 | bafut'
# 'Processing Record 40 in Set 6 | dhidhdhoo'
# 'Processing Record 41 in Set 6 | beyneu'
# 'Processing Record 42 in Set 6 | pilar'
# 'Processing Record 43 in Set 6 | makakilo city'
# 'Processing Record 44 in Set 6 | farafangana'
# 'Processing Record 45 in Set 6 | hashtrud'
# 'Processing Record 46 in Set 6 | balsas'
# 'Processing Record 47 in Set 6 | saint-joseph'
# 'Processing Record 48 in Set 6 | kieta'
# 'Processing Record 49 in Set 6 | oliveira dos brejinhos'
# 'Processing Record 50 in Set 6 | hami'
# 'Processing Record 51 in Set 6 | lomonosov'
# 'Processing Record 52 in Set 6 | macusani'
# 'Processing Record 53 in Set 6 | khonuu'
# 'Missing information for khonuu. Skipping...'
# 'Processing Record 54 in Set 6 | saint-augustin'
# 'Processing Record 55 in Set 6 | ulaanbaatar'
# 'Processing Record 56 in Set 6 | along'
# 'Processing Record 57 in Set 6 | pandrup'
# 'Processing Record 58 in Set 6 | richards bay'
# 'Processing Record 59 in Set 6 | husavik'
# 'Processing Record 60 in Set 6 | cockburn town'
# 'Processing Record 61 in Set 6 | darhan'
# 'Processing Record 62 in Set 6 | qostanay'
# 'Processing Record 63 in Set 6 | dien bien'
# 'Missing information for dien bien. Skipping...'
# 'Processing Record 64 in Set 6 | ahumada'
# 'Missing information for ahumada. Skipping...'
# 'Processing Record 65 in Set 6 | nytva'
# 'Processing Record 66 in Set 6 | moyobamba'
# 'Processing Record 67 in Set 6 | tangier'
# 'Processing Record 68 in Set 6 | dombarovskiy'
# 'Processing Record 69 in Set 6 | hue'
# 'Processing Record 70 in Set 6 | savinka'
# 'Processing Record 71 in Set 6 | skibbereen'
# 'Processing Record 72 in Set 6 | mortka'
# 'Processing Record 73 in Set 6 | teonthar'
# 'Processing Record 74 in Set 6 | yialos'
# 'Missing information for yialos. Skipping...'
# 'Processing Record 75 in Set 6 | port-gentil'
# 'Processing Record 76 in Set 6 | doka'
# 'Processing Record 77 in Set 6 | ambunti'
# 'Processing Record 78 in Set 6 | buraydah'
# 'Processing Record 79 in Set 6 | dakar'
# 'Processing Record 80 in Set 6 | kresttsy'
# 'Processing Record 81 in Set 6 | hukuntsi'
# 'Processing Record 82 in Set 6 | divnomorskoye'
# 'Processing Record 83 in Set 6 | odesskoye'
# 'Processing Record 84 in Set 6 | sirsi'
# 'Processing Record 85 in Set 6 | kang'
# 'Processing Record 86 in Set 6 | riohacha'
# 'Processing Record 87 in Set 6 | haines junction'
# 'Processing Record 88 in Set 6 | coihaique'
# 'Processing Record 89 in Set 6 | sorland'
# 'Processing Record 90 in Set 6 | fomboni'
# 'Processing Record 91 in Set 6 | monzon'
# 'Processing Record 92 in Set 6 | san lawrenz'
# 'Processing Record 93 in Set 6 | faya'
# 'Processing Record 94 in Set 6 | pangnirtung'
# 'Processing Record 95 in Set 6 | udachnyy'
# 'Processing Record 96 in Set 6 | kloulklubed'
# 'Processing Record 97 in Set 6 | shawinigan'
# 'Processing Record 98 in Set 6 | liwale'
# 'Processing Record 99 in Set 6 | kirkenaer'
# 'Processing Record 100 in Set 6 | aitape'
# '-----------------------------'
# 'Data Retrieval Complete'
# '-----------------------------'

# %%
#Concatnate the lists of city data
cities = pd.Series(cities)
countries = pd.Series(countries)
Lat = pd.Series(Lat)
Lng = pd.Series(Lng)
Date = pd.Series(Date)
Max_Temp = pd.Series(Max_Temp)
Cloudiness = pd.Series(Cloudiness)
Humidity = pd.Series(Humidity)
Wind_Speed = pd.Series(Wind_Speed)

city_data = pd.concat([cities, countries, Lat, Lng, Date, Max_Temp, Cloudiness, Humidity, Wind_Speed],
                      axis = 1, join = 'inner')

city_data.columns = ['City', 'Country', 'Lat', 'Lng', 'Date', 'Max Temp (F)', 'Cloudiness',
                                           'Humidity', 'Wind Speed']

#Write the data to the cities.csv file
city_data.to_csv(output_data_file, index = False, header = True)

#Create a dataframe of the cities csv file
city_df = pd.read_csv(output_data_file)

city_df.head(10)

# %% [markdown]
# ## SCATTER PLOTS

# %%
#Loop through cities csv file to create the 'City Latitude vx. Max Temp' scatter plot
x = []
y = []

with open(output_data_file) as city_file:
    
    plot = pd.read_csv(city_file, delimiter = ',')
    
    for lat in plot['Lat']:
        x.append(lat)
        
    for temp in plot['Max Temp (F)']:
        y.append(temp)
        
        
x_limit = 360
x_axis = np.arange(0, x_limit, 10)

plt.scatter(x, y, marker = 'o', facecolors = 'g', edgecolors = 'b', s = x_axis, alpha = 0.25)

plt.title('City Latitude vs. Max Temperature (F) (01/23/2019)')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.grid()

plt.show()

plt.savefig('../output_data/LatvTemp')

# %% [markdown]
# The above scatter plot shows that as the cities are more north of the celestial equator, the maximum temperature is lower.  Whereas, the cities below the equator have higher maximum temperatures with a couple of outliers.

# %%
#Loop through cities csv file to create the 'City Latitude vx. Humidity' scatter plot
x = []
y = []

with open(output_data_file) as city_file:
    
    plot = pd.read_csv(city_file, delimiter = ',')
    
    for lat in plot['Lat']:
        x.append(lat)
        
    for humidity in plot['Humidity']:
        y.append(humidity)
        
        
x_limit = 360
x_axis = np.arange(0, x_limit, 10)
y_limit = 300
y_axis = np.arange(0, y_limit, 100)

plt.scatter(x, y, marker = 'o', facecolors = 'g', edgecolors = 'b', s = x_axis, alpha = 0.25)

plt.title('City Latitude vs. Humidity % (01/23/2019)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

plt.show()

plt.savefig('../output_data/LatvHumidity')

# %% [markdown]
# The 'City Latitude vs. Humidity % (01/23/2019)' scatter plot shows that the humidiy is not dependent on the latitude.

# %%
#Loop through cities csv file to create the 'City Latitude vx. Cloudiness' scatter plot
x = []
y = []

with open(output_data_file) as city_file:
    
    plot = pd.read_csv(city_file, delimiter = ',')
    
    for lat in plot['Lat']:
        x.append(lat)
        
    for cloudiness in plot['Cloudiness']:
        y.append(cloudiness)
        
        
x_limit = 360
x_axis = np.arange(0, x_limit, 10)
y_limit = 80
y_axis = np.arange(0, y_limit, 10)

plt.scatter(x, y, marker = 'o', facecolors = 'g', edgecolors = 'b', s = x_axis, alpha = 0.25)

plt.title('City Latitude vs. Cloudiness (%) (01/23/2019)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

plt.show()

plt.savefig('../output_data/LatvCloudiness')

# %% [markdown]
# The above scatter plot demonstrates that the location of the city is not a determining factor for how cloudy a city is.

# %%
#Loop through cities csv file to create the 'City Latitude vx. Wind Speed' scatter plot
x = []
y = []

with open(output_data_file) as city_file:
    
    plot = pd.read_csv(city_file, delimiter = ',')
    
    for lat in plot['Lat']:
        x.append(lat)
        
    for wind_speed in plot['Wind Speed']:
        y.append(wind_speed)
        
        
x_limit = 360
x_axis = np.arange(0, x_limit, 10)
y_limit = 80
y_axis = np.arange(0, y_limit, 100)

plt.scatter(x, y, marker = 'o', facecolors = 'g', edgecolors = 'b', s = x_axis, alpha = 0.25)

plt.title('City Latitude vs. Wind Speed (mph) (01/23/2019)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()

plt.show()

plt.savefig('../output_data/LatvWindSpeed')

# %% [markdown]
# The above 'Latitude vs. Wind Speed' plot shows that the spped of the wind is not dependent on the latitude.

# %% [markdown]
# ## Linear Regressions

# %%
# Create Northern and Southern Hemisphere DataFrames

North_Hemisphere_df = city_df.loc[city_df['Lat'] >= 0, :]
South_Hemisphere_df = city_df.loc[city_df['Lat'] < 0, :]

# %% [markdown]
# ### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create the linear regression for the cities' max temperature vs. the northern latitudes
x = North_Hemisphere_df['Lat']
y = North_Hemisphere_df['Max Temp (F)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
print(f'The r-squared is: {rvalue}')

plt.scatter(x,y)
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title('Northern Hemisphere - Max Temp vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')

plt.show()

# %% [markdown]
# The above regression demonstrates that the higher the city's latitude, the lower the max temperature will be.

# %% [markdown]
# ### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create the linear regression for the cities' max temperature vs. the southern latitudes
x = South_Hemisphere_df['Lat']
y = South_Hemisphere_df['Max Temp (F)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
print(f'The r-squared is: {rvalue}')

plt.scatter(x,y)
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq, xy=(-50, 60), xytext=(-30, 52), fontsize=15,color="red")

plt.title('Southern Hemisphere - Max Temp vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')

plt.show()

# %% [markdown]
# The above regression shos that the maximum temperature is less dependent on the southern latitude as it has many outliers.

# %% [markdown]
# ### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Create the linear regression for the cities' humidity vs. the northern latitudes
x = North_Hemisphere_df['Lat']
y = North_Hemisphere_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
print(f'The r-squared is: {rvalue}')

plt.scatter(x,y)
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq,(30,30),fontsize=15,color="red")

plt.title('Northern Hemisphere - Humidity vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

plt.show()

# %% [markdown]
# It's more likely that cities north of the equator will have high humidity, but there are many outliers.

# %% [markdown]
# ### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Create the linear regression for the cities' humidity vs. the southern latitudes
x = South_Hemisphere_df['Lat']
y = South_Hemisphere_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
print(f'The r-squared is: {rvalue}')

plt.scatter(x,y)
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq, xy=(-50, 60), xytext=(-30, 30), fontsize=15,color="red")

plt.title('Southern Hemisphere - Humidity vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

plt.show()

# %% [markdown]
# As the southern cities' latitudes approach the equator, the more humidity is in the air, but there are too many outliers.

# %% [markdown]
# ###  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Create the linear regression for the cities' cloudiness vs. the northern latitudes
x = North_Hemisphere_df['Lat']
y = North_Hemisphere_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
print(f'The r-squared is: {rvalue}')

plt.scatter(x,y)
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq,(30,30),fontsize=15,color="red")

plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

plt.show()

# %% [markdown]
# The above linear regression show that as the city is higher than the equator, it should have more clouds but there are too many outliers.

# %% [markdown]
# ###  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Create the linear regression for the cities' cloudiness vs. the southern latitudes
x = South_Hemisphere_df['Lat']
y = South_Hemisphere_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
print(f'The r-squared is: {rvalue}')

plt.scatter(x,y)
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq, xy=(-50, 60), xytext=(-30, 30), fontsize=15,color="red")

plt.title('Southern Hemisphere - Cloudiness(%`) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

plt.show()

# %% [markdown]
# This regression reiterates the Northern regression in that the higher the city's latitude, the cloudier the city but there are too many outliers.

# %% [markdown]
# ### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Create the linear regression for the cities' wind speed vs. the northern latitudes
x = North_Hemisphere_df['Lat']
y = North_Hemisphere_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
print(f'The r-squared is: {rvalue}')

plt.scatter(x,y)
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq,(30,30),fontsize=15,color="red")

plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

plt.show()

# %% [markdown]
# The windy cities are farther north of the equator, but I wouldn't make that definitive due to the many outliers.

# %% [markdown]
# ###  Southern  Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Create the linear regression for the cities' wind speed vs. the southern latitudes
x = South_Hemisphere_df['Lat']
y = South_Hemisphere_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
print(f'The r-squared is: {rvalue}')

plt.scatter(x,y)
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq, xy=(-50, 20), xytext=(-30, 25), fontsize=15,color="red")

plt.title('Southern Hemisphere - Wind Speed (mph`) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

plt.show()

# %% [markdown]
# The cities that are farther south of the equator are very windy.
